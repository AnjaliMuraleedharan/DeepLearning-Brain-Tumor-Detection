# %% [markdown]
# # Import Statements

# %%
import os
import keras 
from keras.models import Sequential
from keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout, BatchNormalization
from PIL import Image
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import OneHotEncoder

# %% [markdown]
# # One Hot Encoding the Target Classes

# %%
encoder = OneHotEncoder()
encoder.fit([[0], [1]]) 

# 0 - Tumor
# 1 - Normal
# Out:
# OneHotEncoder()

# %% [markdown]
# # Creating 3 Important Lists --
# 1. data -for storing image data in numpy array form
# 2. paths - for storing paths of all the images
# 3. result -for storing one hot encoded form of target class whether normal or tumor

# %%
# This cell updates result list for images with tumor

data = []
paths = []
result = []

for r, d, f in os.walk(r'../input/brain-mri-images-for-brain-tumor-detection/yes'):
    for file in f:
        if '.jpg' in file:
            paths.append(os.path.join(r, file))

for path in paths:
    img = Image.open(path)
    img = img.resize((128,128))
    img = np.array(img)
    if(img.shape == (128,128,3)):
        data.append(np.array(img))
        result.append(encoder.transform([[0]]).toarray())

# %%
# This cell updates result list for images without tumor

paths = []
for r, d, f in os.walk(r"../input/brain-mri-images-for-brain-tumor-detection/no"):
    for file in f:
        if '.jpg' in file:
            paths.append(os.path.join(r, file))

for path in paths:
    img = Image.open(path)
    img = img.resize((128,128))
    img = np.array(img)
    if(img.shape == (128,128,3)):
        data.append(np.array(img))
        result.append(encoder.transform([[1]]).toarray())

# %%
data = np.array(data)
data.shape
# Out:
# (139, 128, 128, 3)

# %%
result = np.array(result)
result = result.reshape(139,2)

# %% [markdown]
# # Splitting the Data into Training & Testing

# %%
x_train,x_test,y_train,y_test = train_test_split(data, result, test_size=0.2, shuffle=True, random_state=0)

# %% [markdown]
# # Model Building

# %%
model = Sequential()

model.add(Conv2D(32, kernel_size=(2, 2), input_shape=(128, 128, 3), padding = 'Same'))
model.add(Conv2D(32, kernel_size=(2, 2),  activation ='relu', padding = 'Same'))


model.add(BatchNormalization())
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.25))

model.add(Conv2D(64, kernel_size = (2,2), activation ='relu', padding = 'Same'))
model.add(Conv2D(64, kernel_size = (2,2), activation ='relu', padding = 'Same'))

model.add(BatchNormalization())
model.add(MaxPooling2D(pool_size=(2,2), strides=(2,2)))
model.add(Dropout(0.25))

model.add(Flatten())

model.add(Dense(512, activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(2, activation='softmax'))

model.compile(optimizer='Adamax', loss="categorical_crossentropy", metrics=['accuracy'])
print(model.summary())
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 128, 128, 32)      416
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 128, 128, 32)      4128
# _________________________________________________________________
# batch_normalization (BatchNo (None, 128, 128, 32)      128
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 64, 64, 32)        0
# _________________________________________________________________
# dropout (Dropout)            (None, 64, 64, 32)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 64, 64, 64)        8256
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 64, 64, 64)        16448
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 64, 64, 64)        256
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 32, 32, 64)        0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 32, 32, 64)        0
# _________________________________________________________________
# flatten (Flatten)            (None, 65536)             0
# _________________________________________________________________
# dense (Dense)                (None, 512)               33554944
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 512)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 2)                 1026
# =================================================================
# Total params: 33,585,602
# Trainable params: 33,585,410
# Non-trainable params: 192
# _________________________________________________________________
# None

# %%
y_train.shape
# Out:
# (111, 2)

# %%
history = model.fit(x_train, y_train, epochs = 30, batch_size = 40, verbose = 1,validation_data = (x_test, y_test))
# Out:
# Epoch 1/30
# 3/3 [==============================] - 4s 1s/step - loss: 56.9104 - accuracy: 0.4955 - val_loss: 100.2809 - val_accuracy: 0.5000
# Epoch 2/30
# 3/3 [==============================] - 7s 2s/step - loss: 28.0303 - accuracy: 0.6577 - val_loss: 76.8608 - val_accuracy: 0.5000
# Epoch 3/30
# 3/3 [==============================] - 5s 2s/step - loss: 14.4169 - accuracy: 0.7027 - val_loss: 7.4889 - val_accuracy: 0.7143
# Epoch 4/30
# 3/3 [==============================] - 3s 950ms/step - loss: 7.2794 - accuracy: 0.7477 - val_loss: 14.0265 - val_accuracy: 0.6071
# Epoch 5/30
# 3/3 [==============================] - 3s 916ms/step - loss: 5.5846 - accuracy: 0.7477 - val_loss: 3.2466 - val_accuracy: 0.7143
# Epoch 6/30
# 3/3 [==============================] - 3s 945ms/step - loss: 2.4964 - accuracy: 0.7838 - val_loss: 9.9537 - val_accuracy: 0.6429
# Epoch 7/30
# 3/3 [==============================] - 3s 912ms/step - loss: 2.1169 - accuracy: 0.8468 - val_loss: 14.7139 - val_accuracy: 0.6071
# Epoch 8/30
# 3/3 [==============================] - 3s 1s/step - loss: 2.7872 - accuracy: 0.8108 - val_loss: 10.1715 - val_accuracy: 0.6071
# Epoch 9/30
# 3/3 [==============================] - 3s 921ms/step - loss: 1.4049 - accuracy: 0.8829 - val_loss: 4.5464 - val_accuracy: 0.7857
# Epoch 10/30
# 3/3 [==============================] - 3s 923ms/step - loss: 0.2847 - accuracy: 0.9099 - val_loss: 1.5034 - val_accuracy: 0.7857
# Epoch 11/30
# 3/3 [==============================] - 3s 1s/step - loss: 0.3878 - accuracy: 0.9009 - val_loss: 1.1218 - val_accuracy: 0.6786
# Epoch 12/30
# 3/3 [==============================] - 3s 977ms/step - loss: 0.7008 - accuracy: 0.9009 - val_loss: 1.0787 - val_accuracy: 0.7500
# Epoch 13/30
# 3/3 [==============================] - 3s 950ms/step - loss: 0.1738 - accuracy: 0.9369 - val_loss: 0.8134 - val_accuracy: 0.7857
# Epoch 14/30
# 3/3 [==============================] - 3s 913ms/step - loss: 0.1560 - accuracy: 0.9550 - val_loss: 0.7240 - val_accuracy: 0.8214
# Epoch 15/30
# 3/3 [==============================] - 3s 1s/step - loss: 0.1139 - accuracy: 0.9820 - val_loss: 1.1804 - val_accuracy: 0.8214
# Epoch 16/30
# 3/3 [==============================] - 3s 940ms/step - loss: 0.0146 - accuracy: 0.9910 - val_loss: 1.7209 - val_accuracy: 0.7857
# Epoch 17/30
# 3/3 [==============================] - 3s 896ms/step - loss: 0.0750 - accuracy: 0.9910 - val_loss: 2.0075 - val_accuracy: 0.7857
# Epoch 18/30
# 3/3 [==============================] - 3s 895ms/step - loss: 0.0401 - accuracy: 0.9820 - val_loss: 2.0304 - val_accuracy: 0.7857
# Epoch 19/30
# 3/3 [==============================] - 3s 906ms/step - loss: 0.0472 - accuracy: 0.9910 - val_loss: 1.9654 - val_accuracy: 0.7857
# Epoch 20/30
# 3/3 [==============================] - 3s 909ms/step - loss: 0.0114 - accuracy: 1.0000 - val_loss: 1.7521 - val_accuracy: 0.7857
# Epoch 21/30
# 3/3 [==============================] - 3s 928ms/step - loss: 0.0161 - accuracy: 0.9910 - val_loss: 1.5634 - val_accuracy: 0.7857
# Epoch 22/30
# 3/3 [==============================] - 3s 908ms/step - loss: 0.1466 - accuracy: 0.9910 - val_loss: 1.2835 - val_accuracy: 0.7857
# Epoch 23/30
# 3/3 [==============================] - 3s 1s/step - loss: 0.0825 - accuracy: 0.9820 - val_loss: 0.9622 - val_accuracy: 0.8214
# Epoch 24/30
# 3/3 [==============================] - 3s 945ms/step - loss: 0.0312 - accuracy: 0.9910 - val_loss: 0.6827 - val_accuracy: 0.8571
# Epoch 25/30
# 3/3 [==============================] - 3s 980ms/step - loss: 0.0665 - accuracy: 0.9910 - val_loss: 0.5700 - val_accuracy: 0.8571
# Epoch 26/30
# 3/3 [==============================] - 3s 926ms/step - loss: 8.3555e-04 - accuracy: 1.0000 - val_loss: 0.5091 - val_accuracy: 0.8571
# Epoch 27/30
# 3/3 [==============================] - 3s 921ms/step - loss: 0.0019 - accuracy: 1.0000 - val_loss: 0.4755 - val_accuracy: 0.8571
# Epoch 28/30
# 3/3 [==============================] - 3s 903ms/step - loss: 0.0177 - accuracy: 1.0000 - val_loss: 0.4618 - val_accuracy: 0.8571
# Epoch 29/30
# 3/3 [==============================] - 3s 936ms/step - loss: 0.0034 - accuracy: 1.0000 - val_loss: 0.4571 - val_accuracy: 0.8571
# Epoch 30/30
# 3/3 [==============================] - 3s 907ms/step - loss: 9.1998e-04 - accuracy: 1.0000 - val_loss: 0.4534 - val_accuracy: 0.8571

# %% [markdown]
# # Plotting Losses and Accuracies

# %%
# Loss
plt.plot(history.history['loss'], label='Train')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.title('Loss')
plt.legend()
plt.show()

# %%
# Accuracy
plt.plot(history.history['accuracy'], label='Training Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Acc')
plt.title('Accuracy')
plt.legend()
plt.show()

# %% [markdown]
# # Checking the Model

# %%
def names(number):
    if number==0:
        return 'Its a Tumor'
    else:
        return 'No, Its not a tumor'

# %%
from matplotlib.pyplot import imshow
img = Image.open(r"../input/brain-mri-images-for-brain-tumor-detection/no/N17.jpg")
x = np.array(img.resize((128,128)))
x = x.reshape(1,128,128,3)
res = model.predict_on_batch(x)
classification = np.where(res == np.amax(res))[1][0]
imshow(img)
print(str(res[0][classification]*100) + '% Confidence This Is ' + names(classification))
# Out:
# 99.99997615814209% Confidence This Is No, Its not a tumor

# %%
from matplotlib.pyplot import imshow
img = Image.open(r"../input/brain-mri-images-for-brain-tumor-detection/yes/Y3.jpg")
x = np.array(img.resize((128,128)))
x = x.reshape(1,128,128,3)
res = model.predict_on_batch(x)
classification = np.where(res == np.amax(res))[1][0]
imshow(img)
print(str(res[0][classification]*100) + '% Confidence This Is A ' + names(classification))
# Out:
# 99.89262223243713% Confidence This Is A Its a Tumor

# %% [markdown]
# # END
